# %% [markdown]
# # Get pitch and yaw Angles

# %%
import numpy as np
import cv2

# Define the path to the labeled videos and corresponding label files
labels_path = '../folder/label_34/'

# Define the number of frames in each video (assumed to be the same for all videos)
num_frames = 1200

# nparay for all angles
angles_labeled = []

# frames
frames = []

# Initialize an array to store the pitch and yaw angles for each frame
# angles = np.zeros((num_frames * 5, 2))
angles = []

# Load the labeled videos and extract the pitch and yaw angles for each frame
for i in range(4):

    # Load the label file
    labels = np.loadtxt(labels_path + str(i) + '.txt')

    lenght_label = len(labels)
    diff_lenght = num_frames - lenght_label

    # Iterate over each frame in the video
    for j in range(lenght_label):

        # Estimate the pitch and yaw angles for the current frame using the labels
        pitch = labels[j, 0]
        yaw = labels[j, 1]

        angles.append((pitch,yaw))
    
    if diff_lenght > 0:
        for k in range(diff_lenght):
            angles.append((None,None))
        

    # Print the shape of the angles array for verification
    #print(f"Angles shape for video {i}: {angles.shape}")

# Convert the list of frames to a numpy array
angles_array_labeled = np.array(angles, dtype = np.float32)
print(f"Frames shape for video : {angles_array_labeled.shape}")
#print(angles_array_labeled[0][0])
# Out:
# Frames shape for video : (4800, 2)

# %% [markdown]
# ## Preprocess and normalize function for a frame

# %%
import cv2
import numpy as np

# Define the desired width and height of the frames after resizing
width = 232
height = 174

# Define the normalization parameters
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# Define the intrinsic camera matrix
K = np.array([[910, 0, 0],
              [0, 910, 0],
              [0, 0, 1]])

# Define a function to preprocess a frame
def preprocess_frame(frame):
    # Undistort the frame using the intrinsic camera matrix
    undistorted_frame = cv2.undistort(frame, K, None)

    # Resize the frame to the desired dimensions
    resized_frame = cv2.resize(undistorted_frame, (width, height))

    # grayscale image
    #resized_frame = cv2.cvtColor(resized_frame, cv2.COLOR_RGB2GRAY)

    # bgr
    #resized_frame = cv2.cvtColor(resized_frame, cv2.COLOR_RGB2BGR)

    # HSV
    resized_frame = cv2.cvtColor(resized_frame, cv2.COLOR_RGB2HSV)
    # V value = 0
    resized_frame[..., 2] = resized_frame[..., 2] * 0

    # Convert the frame to float32 data type
    normalized_frame = resized_frame.astype(np.float32)

    # Normalize the frame using the defined mean and standard deviation
    normalized_frame /= 255.0
    #normalized_frame -= mean
    #normalized_frame /= std

    return normalized_frame

# %% [markdown]
# # Get and preprocess Labeled Frame

# %%
# Define the path to the labeled videos
videos_path = '../folder/label_34/'


# Define the number of frames in each video (assumed to be the same for all videos)
num_frames = 1200

# Define a default frame to use for filling in missing frames
default_frame = np.zeros((height, width, 3), dtype=np.float32)

# Initialize a list to store the frames for each video
frames_list = []

# Iterate over each video
for i in range(4):
    # Load the video
    video = cv2.VideoCapture(videos_path + str(i) + '.hevc')

    # Initialize an empty list to store the frames for the current video
    frames = []

    # Iterate over each frame in the video
    for j in range(num_frames):
        # Read the frame
        ret, frame = video.read()

        # Check if the frame was successfully read
        if not ret:
            # If the frame was not read, use the default frame instead
            frame = default_frame

        frame = preprocess_frame(frame)
        
        # Append the frame to the list of frames for the current video
        #frames.append(frame)
        frames_list.append(frame)

    # Release the video object
    video.release()


    # Convert the list of frames to a numpy array
    frames_array_labeled = np.array(frames_list)
    print(f"Frames shape for video {i}: {frames_array_labeled.shape}")

# Convert the list of frames to a numpy array
frames_array_labeled = np.array(frames_list)
print(f"Frames shape for video : {frames_array_labeled.shape}")


# Print the shape of the frames list for verification
print(f"Frames shape: {len(frames_list)} videos, {len(frames_list[0])} frames per video, {len(frames_list[0])}x{len(frames_list[0][0])} pixels")
# Out:
# Frames shape for video 0: (1200, 174, 232, 3)
# Frames shape for video 1: (2400, 174, 232, 3)
# Frames shape for video 2: (3600, 174, 232, 3)
# Frames shape for video 3: (4800, 174, 232, 3)
# Frames shape for video : (4800, 174, 232, 3)
# Frames shape: 4800 videos, 174 frames per video, 174x232 pixels

# %% [markdown]
# * Delete NaN data

# %%
# Find the indices where either pitch or yaw angle is nan
nan_idx = np.where(np.isnan(angles_array_labeled[:,0]) | np.isnan(angles_array_labeled[:,1]))

# Delete the corresponding rows from frames_array_labeled and angles_array_labeled
frames_array_labeled = np.delete(frames_array_labeled, nan_idx, axis=0)
angles_array_labeled = np.delete(angles_array_labeled, nan_idx, axis=0)

# Print the shape of the frames and angles arrays after removing NaN values
print(f"Frames shape: {frames_array_labeled.shape}")
print(f"Angles shape: {angles_array_labeled.shape}")
# Out:
# Frames shape: (4165, 174, 232, 3)
# Angles shape: (4165, 2)

# %% [markdown]
# * Plot some frames

# %%
import matplotlib.pyplot as plt

# Define the number of frames to plot
num_frames_to_plot = 5

# Create a figure with multiple subplots
fig, axes = plt.subplots(1, num_frames_to_plot, figsize=(20, 10))

# Plot the first num_frames_to_plot frames from the list
for i in range(num_frames_to_plot):
    axes[i].imshow(frames_list[i])
    axes[i].axis('off')

# Show the plot
plt.show()

# %% [markdown]
# # WandB

# %%
import wandb
from wandb.keras import WandbCallback

# !wandb login 9ac325ccaea24e6579ccfd48050d0069010acb93
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\youss/.netrc

# %%
# Start a run, tracking hyperparameters
wandb.init(
    # set the wandb project where this run will be logged
    project="calib_challenge",

    # track hyperparameters and run metadata with wandb.config
    config={
        "layer_1": 32,
        "activation_1": "relu",
        "layer_2": 64,
        "activation_2": "relu",
        "layer_2": 128,
        "dense": 256,
        "activation_3": "relu",
        "dropout": 0.8,
        "dense": 2,
        "activation_4": "relu",
        "optimizer": "adam",
        "loss": "mse",
        "metric": "accuracy",
        "epoch": 20,
        "batch_size": 32
    }
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ykhouchaf. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>c:\Users\youss\Desktop\Youssef\Stage2\Tests\calib_challenge-main\notebooks\wandb\run-20230225_014328-ly2y21rc</code>
# Syncing run <strong><a href='https://wandb.ai/ykhouchaf/calib_challenge/runs/ly2y21rc' target="_blank">lyric-yogurt-5</a></strong> to <a href='https://wandb.ai/ykhouchaf/calib_challenge' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ykhouchaf/calib_challenge' target="_blank">https://wandb.ai/ykhouchaf/calib_challenge</a>
#  View run at <a href='https://wandb.ai/ykhouchaf/calib_challenge/runs/ly2y21rc' target="_blank">https://wandb.ai/ykhouchaf/calib_challenge/runs/ly2y21rc</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/ykhouchaf/calib_challenge/runs/ly2y21rc?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# # Convolutional neural network (CNN)

# %% [markdown]
# * classic

# %%
from tensorflow import keras

# Define the input shape of the frames (assumed to be the same for all frames)
input_shape = (height, width, 3)
# Input shape if gray 
input_shape_gray = (height, width, 1)

# Define the number of output nodes (2 for pitch and yaw)
num_outputs = 2

# Define the CNN model
model = keras.Sequential([
    keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_outputs, activation='linear')
])

# Compile the model with the mean squared error loss and the Adam optimizer
#model.compile(loss='mse', optimizer='adam', metrics=['mse'])
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mse', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# * Classic with more layers

# %%
from tensorflow import keras

# Define the input shape of the frames (assumed to be the same for all frames)
input_shape = (height, width, 3)

# Input shape if gray 
input_shape_gray = (height, width, 1)

# Define the number of output nodes (2 for pitch and yaw)
num_outputs = 2

# Define the CNN model
model = keras.Sequential([
    keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(256, kernel_size=(3, 3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_outputs, activation='linear')
])

# Compile the model with the mean squared error loss and the Adam optimizer
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# * My 16

# %%
from tensorflow import keras

# Define the input shape of the frames (assumed to be the same for all frames)
input_shape = (height, width, 3)

# Define the number of output nodes (2 for pitch and yaw)
num_outputs = 2

# Define the CNN model
model = keras.Sequential([
    keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape),
    keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_outputs, activation='linear')
])

# Add more dropout to reduce overfitting
model.layers[14].rate = 0.5
model.layers[16].rate = 0.5
model.layers[18].rate = 0.5

# Compile the model with the mean squared error loss and the Adam optimizer
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
from tensorflow import keras

# Define the input shape of the frames (assumed to be the same for all frames)
input_shape = (height, width, 3)

# Define the number of output nodes (2 for pitch and yaw)
num_outputs = 2

# Define the CNN model
model = keras.Sequential([
    keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape),
    keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_outputs, activation='linear')
])



# Compile the model with the mean squared error loss and the Adam optimizer
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# * Resnet18

# %%
from tensorflow import keras
from keras.applications.resnet import ResNet18

# Define the input shape of the frames (assumed to be the same for all frames)
input_shape = (224, 224, 3)

# Define the number of output nodes (2 for pitch and yaw)
num_outputs = 2

# Create the ResNet50 model
base_model = ResNet18(include_top=False, input_shape=input_shape, pooling='avg')

# Add the output layer with the specified number of nodes and linear activation function
x = base_model.output
x = keras.layers.Dense(num_outputs, activation='linear')(x)

# Create the final model by combining the base ResNet50 model and the output layer
model = keras.models.Model(inputs=base_model.input, outputs=x)

# Compile the model with the mean squared error loss and the Adam optimizer
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %% [markdown]
# * EfficientNetB0

# %%
from tensorflow import keras
from keras.applications import EfficientNetB0
from keras import regularizers

# Load the pre-trained weights
model_weights = "C:/Users/youss/Desktop/Youssef/Stage2/Tests/noisy_student_efficientnet-b0/efficientnetb0_notop.h5"

num_outputs = 2

# Define the input shape of the frames (assumed to be the same for all frames)
input_shape = (height, width, 3)

# Input shape if gray 
input_shape_gray = (224, 224, 1)

# Create the base model with pre-trained weights
base_model = EfficientNetB0(include_top=False, weights=model_weights, input_shape=input_shape)

# Freeze the pretrained weights
base_model.trainable = False


x = base_model(base_model.input, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
#x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dropout(0.5)(x)

# Add regularizers
reg = regularizers.l2(0.01)

# Add a dense layer with L2 regularization
x = keras.layers.Dense(512, activation='relu', kernel_regularizer=reg)(x)

# Add another dropout layer
x = keras.layers.Dropout(0.5)(x)

outputs = keras.layers.Dense(num_outputs)(x)

# Add your own classification layers
# x = keras.layers.GlobalAveragePooling2D()(model.output)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.Dense(128, activation='relu')(x)
# x = keras.layers.Dropout(0.5)(x)
# x = keras.layers.Dense(num_outputs)(x)

# Create the final model
model = None
model = keras.Model(inputs=base_model.input, outputs=outputs)

model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 174, 232, 3)]     0
#
#  efficientnetb0 (Functional)  (None, 6, 8, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 512)               655872
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 4,706,469
# Trainable params: 656,898
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %% [markdown]
# # Train

# %% [markdown]
# * GPU train if no using model with transfer learning

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator

# frees up any memory that was used during last session
tf.keras.backend.clear_session()

# Split the labeled video data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(frames_array_labeled, angles_array_labeled, test_size=0.2, random_state=1)


# Train the model on the training set using the fit() function and evaluate it with evaluate()
with tf.device('/GPU:0'):
    #history = model.fit(x_train, y_train, batch_size=32, epochs=20, validation_data=(x_val, y_val), callbacks=[WandbCallback()])
    history = model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_val, y_val))
    loss = model.evaluate(x_val, y_val)
print('Validation Loss:', loss)
# Out:
# Epoch 1/50
# 53/53 [==============================] - 8s 115ms/step - loss: 0.0476 - accuracy: 0.8271 - val_loss: 5.7937e-05 - val_accuracy: 0.9868
# Epoch 2/50
# 53/53 [==============================] - 5s 101ms/step - loss: 9.0917e-05 - accuracy: 0.8851 - val_loss: 5.5819e-05 - val_accuracy: 0.7299
# Epoch 3/50
# 53/53 [==============================] - 5s 100ms/step - loss: 8.0159e-05 - accuracy: 0.8980 - val_loss: 1.5620e-05 - val_accuracy: 0.9868
# Epoch 4/50
# 53/53 [==============================] - 5s 101ms/step - loss: 6.3287e-05 - accuracy: 0.9010 - val_loss: 1.5447e-05 - val_accuracy: 0.9868
# Epoch 5/50
# 53/53 [==============================] - 5s 101ms/step - loss: 6.1988e-05 - accuracy: 0.9031 - val_loss: 1.1512e-05 - val_accuracy: 0.8631
# Epoch 6/50
# 53/53 [==============================] - 5s 101ms/step - loss: 5.4559e-05 - accuracy: 0.9064 - val_loss: 1.6493e-05 - val_accuracy: 0.9856
# Epoch 7/50
# 53/53 [==============================] - 5s 101ms/step - loss: 4.8417e-05 - accuracy: 0.8974 - val_loss: 1.1339e-05 - val_accuracy: 0.9868
# Epoch 8/50
# 53/53 [==============================] - 5s 103ms/step - loss: 4.7334e-05 - accuracy: 0.9043 - val_loss: 2.8652e-05 - val_accuracy: 0.8764
# Epoch 9/50
# 53/53 [==============================] - 6s 105ms/step - loss: 5.0304e-05 - accuracy: 0.8977 - val_loss: 5.2056e-06 - val_accuracy: 0.9436
# Epoch 10/50
# 53/53 [==============================] - 6s 104ms/step - loss: 4.2246e-05 - accuracy: 0.9028 - val_loss: 1.7677e-05 - val_accuracy: 0.9388
# Epoch 11/50
# 53/53 [==============================] - 6s 104ms/step - loss: 4.5848e-05 - accuracy: 0.9007 - val_loss: 1.0082e-05 - val_accuracy: 0.9472
# Epoch 12/50
# 53/53 [==============================] - 5s 104ms/step - loss: 3.9452e-05 - accuracy: 0.9022 - val_loss: 6.4269e-06 - val_accuracy: 0.9724
# Epoch 13/50
# 53/53 [==============================] - 5s 103ms/step - loss: 3.8152e-05 - accuracy: 0.9118 - val_loss: 1.2528e-05 - val_accuracy: 0.9424
# Epoch 14/50
# 53/53 [==============================] - 5s 102ms/step - loss: 3.8373e-05 - accuracy: 0.9076 - val_loss: 1.0460e-05 - val_accuracy: 0.7647
# Epoch 15/50
# 53/53 [==============================] - 5s 103ms/step - loss: 3.5370e-05 - accuracy: 0.9028 - val_loss: 1.2382e-05 - val_accuracy: 0.9832
# Epoch 16/50
# 53/53 [==============================] - 5s 103ms/step - loss: 3.6420e-05 - accuracy: 0.9082 - val_loss: 6.3565e-06 - val_accuracy: 0.9352
# Epoch 17/50
# 53/53 [==============================] - 5s 103ms/step - loss: 3.4456e-05 - accuracy: 0.9100 - val_loss: 4.3977e-06 - val_accuracy: 0.9856
# Epoch 18/50
# 53/53 [==============================] - 5s 103ms/step - loss: 3.0860e-05 - accuracy: 0.9175 - val_loss: 4.4394e-06 - val_accuracy: 0.9520
# Epoch 19/50
# 53/53 [==============================] - 5s 103ms/step - loss: 3.1238e-05 - accuracy: 0.9163 - val_loss: 3.6422e-06 - val_accuracy: 0.9148
# Epoch 20/50
# 53/53 [==============================] - 5s 103ms/step - loss: 3.0146e-05 - accuracy: 0.9130 - val_loss: 6.6653e-06 - val_accuracy: 0.9688
# Epoch 21/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.7869e-05 - accuracy: 0.9181 - val_loss: 9.5062e-06 - val_accuracy: 0.9832
# Epoch 22/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.6779e-05 - accuracy: 0.9181 - val_loss: 7.8149e-06 - val_accuracy: 0.9760
# Epoch 23/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.9455e-05 - accuracy: 0.9124 - val_loss: 8.5466e-06 - val_accuracy: 0.9736
# Epoch 24/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.8973e-05 - accuracy: 0.9229 - val_loss: 5.3550e-06 - val_accuracy: 0.9436
# Epoch 25/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.4923e-05 - accuracy: 0.9172 - val_loss: 3.3457e-06 - val_accuracy: 0.9592
# Epoch 26/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.4203e-05 - accuracy: 0.9211 - val_loss: 5.6141e-06 - val_accuracy: 0.9400
# Epoch 27/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.3690e-05 - accuracy: 0.9127 - val_loss: 3.4148e-06 - val_accuracy: 0.9808
# Epoch 28/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.2467e-05 - accuracy: 0.9283 - val_loss: 6.9404e-06 - val_accuracy: 0.9364
# Epoch 29/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.1356e-05 - accuracy: 0.9151 - val_loss: 3.5970e-06 - val_accuracy: 0.9808
# Epoch 30/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.1103e-05 - accuracy: 0.9271 - val_loss: 3.1037e-06 - val_accuracy: 0.9616
# Epoch 31/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.0705e-05 - accuracy: 0.9280 - val_loss: 4.2656e-06 - val_accuracy: 0.9532
# Epoch 32/50
# 53/53 [==============================] - 5s 103ms/step - loss: 2.0136e-05 - accuracy: 0.9268 - val_loss: 2.8235e-06 - val_accuracy: 0.9760
# Epoch 33/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.9071e-05 - accuracy: 0.9340 - val_loss: 2.9906e-06 - val_accuracy: 0.9760
# Epoch 34/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.8527e-05 - accuracy: 0.9277 - val_loss: 4.9625e-06 - val_accuracy: 0.9832
# Epoch 35/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.8985e-05 - accuracy: 0.9271 - val_loss: 3.2407e-06 - val_accuracy: 0.9436
# Epoch 36/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.8408e-05 - accuracy: 0.9259 - val_loss: 5.3506e-06 - val_accuracy: 0.9700
# Epoch 37/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.7497e-05 - accuracy: 0.9358 - val_loss: 2.8894e-06 - val_accuracy: 0.9700
# Epoch 38/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.9475e-05 - accuracy: 0.9316 - val_loss: 3.5046e-06 - val_accuracy: 0.9688
# Epoch 39/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.7169e-05 - accuracy: 0.9343 - val_loss: 3.1764e-06 - val_accuracy: 0.9556
# Epoch 40/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.6558e-05 - accuracy: 0.9334 - val_loss: 2.5691e-06 - val_accuracy: 0.9412
# Epoch 41/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.6515e-05 - accuracy: 0.9394 - val_loss: 5.0260e-06 - val_accuracy: 0.8367
# Epoch 42/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.6881e-05 - accuracy: 0.9433 - val_loss: 2.8637e-06 - val_accuracy: 0.9376
# Epoch 43/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.7439e-05 - accuracy: 0.9415 - val_loss: 3.4876e-06 - val_accuracy: 0.9856
# Epoch 44/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.6407e-05 - accuracy: 0.9412 - val_loss: 3.6888e-06 - val_accuracy: 0.9856
# Epoch 45/50
# 53/53 [==============================] - 5s 104ms/step - loss: 1.5901e-05 - accuracy: 0.9469 - val_loss: 2.5494e-06 - val_accuracy: 0.9748
# Epoch 46/50
# 53/53 [==============================] - 5s 104ms/step - loss: 1.4928e-05 - accuracy: 0.9448 - val_loss: 4.1171e-06 - val_accuracy: 0.9796
# Epoch 47/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.5071e-05 - accuracy: 0.9463 - val_loss: 8.0160e-06 - val_accuracy: 0.8223
# Epoch 48/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.4913e-05 - accuracy: 0.9493 - val_loss: 4.0531e-06 - val_accuracy: 0.9808
# Epoch 49/50
# 53/53 [==============================] - 5s 104ms/step - loss: 1.4506e-05 - accuracy: 0.9496 - val_loss: 3.4286e-06 - val_accuracy: 0.9856
# Epoch 50/50
# 53/53 [==============================] - 5s 103ms/step - loss: 1.4141e-05 - accuracy: 0.9496 - val_loss: 3.2565e-06 - val_accuracy: 0.9520
# 27/27 [==============================] - 1s 18ms/step - loss: 3.2565e-06 - accuracy: 0.9520
# Validation Loss: [3.25647170029697e-06, 0.9519807696342468]

# %% [markdown]
# * Tranfer learning, Unfreez and Train

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping


# frees up any memory that was used during last session
tf.keras.backend.clear_session()

# Unfreeze the model
base_model.trainable = True
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])


# Split the labeled video data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(frames_array_labeled, angles_array_labeled, test_size=0.2, random_state=1)

# # Define data augmentation parameters
# data_gen = ImageDataGenerator(brightness_range=(0.75, 1))

# # Generate augmented images
# augmented_images = data_gen.flow(x_train, y_train, batch_size=32)

# Define early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=2, restore_best_weights=True)

# Train the model on the training set using the fit() function and evaluate it with evaluate()
with tf.device('/GPU:0'):
    history = model.fit(x_train, y_train, batch_size=32, epochs=20, validation_data=(x_val, y_val))
    loss = model.evaluate(x_val, y_val)
print('Validation Loss:', loss)
# Out:
# Epoch 1/20
# 105/105 [==============================] - 21s 131ms/step - loss: 5.7777 - accuracy: 0.4970 - val_loss: 3.3568 - val_accuracy: 0.5738
# Epoch 2/20
# 105/105 [==============================] - 12s 117ms/step - loss: 2.7457 - accuracy: 0.5063 - val_loss: 2.3193 - val_accuracy: 0.4262
# Epoch 3/20
# 105/105 [==============================] - 12s 117ms/step - loss: 2.0463 - accuracy: 0.5081 - val_loss: 1.8026 - val_accuracy: 0.5738
# Epoch 4/20
# 105/105 [==============================] - 12s 117ms/step - loss: 1.6198 - accuracy: 0.5036 - val_loss: 1.4500 - val_accuracy: 0.5738
# Epoch 5/20
# 105/105 [==============================] - 12s 117ms/step - loss: 1.3157 - accuracy: 0.5006 - val_loss: 1.1886 - val_accuracy: 0.4262
# Epoch 6/20
# 105/105 [==============================] - 12s 117ms/step - loss: 1.0852 - accuracy: 0.4997 - val_loss: 0.9864 - val_accuracy: 0.4262
# Epoch 7/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.9046 - accuracy: 0.5165 - val_loss: 0.8258 - val_accuracy: 0.5738
# Epoch 8/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.7598 - accuracy: 0.5168 - val_loss: 0.6959 - val_accuracy: 0.4262
# Epoch 9/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.6419 - accuracy: 0.4874 - val_loss: 0.5894 - val_accuracy: 0.4262
# Epoch 10/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.5448 - accuracy: 0.4895 - val_loss: 0.5012 - val_accuracy: 0.4262
# Epoch 11/20
# 105/105 [==============================] - 12s 118ms/step - loss: 0.4639 - accuracy: 0.4979 - val_loss: 0.4275 - val_accuracy: 0.4262
# Epoch 12/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.3962 - accuracy: 0.5033 - val_loss: 0.3655 - val_accuracy: 0.4262
# Epoch 13/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.3390 - accuracy: 0.4916 - val_loss: 0.3131 - val_accuracy: 0.5738
# Epoch 14/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.2906 - accuracy: 0.4991 - val_loss: 0.2686 - val_accuracy: 0.4262
# Epoch 15/20
# 105/105 [==============================] - 12s 119ms/step - loss: 0.2494 - accuracy: 0.4952 - val_loss: 0.2306 - val_accuracy: 0.4262
# Epoch 16/20
# 105/105 [==============================] - 12s 118ms/step - loss: 0.2143 - accuracy: 0.4946 - val_loss: 0.1982 - val_accuracy: 0.4262
# Epoch 17/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.1842 - accuracy: 0.5000 - val_loss: 0.1704 - val_accuracy: 0.5738
# Epoch 18/20
# 105/105 [==============================] - 12s 118ms/step - loss: 0.1584 - accuracy: 0.5033 - val_loss: 0.1466 - val_accuracy: 0.5738
# Epoch 19/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.1363 - accuracy: 0.4934 - val_loss: 0.1261 - val_accuracy: 0.5738
# Epoch 20/20
# 105/105 [==============================] - 12s 117ms/step - loss: 0.1172 - accuracy: 0.4763 - val_loss: 0.1084 - val_accuracy: 0.5738
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1084 - accuracy: 0.5738
# Validation Loss: [0.10839566588401794, 0.5738295316696167]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# * Datagen

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping

# frees up any memory that was used during last session
tf.keras.backend.clear_session()

# Split the labeled video data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(frames_array_labeled, angles_array_labeled, test_size=0.2, random_state=1)

# Define data augmentation parameters
data_gen = ImageDataGenerator(brightness_range=(0.75, 1))

# Generate augmented images
augmented_images = data_gen.flow(x_train, y_train, batch_size=32)

# Define early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

# Train the model on the training set using the fit() function and evaluate it with evaluate()
with tf.device('/GPU:0'):
    history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data=(x_val, y_val))
    loss = model.evaluate(x_val, y_val)
print('Validation Loss:', loss)
# Out:
# Epoch 1/100
# 105/105 [==============================] - 13s 89ms/step - loss: 0.0463 - accuracy: 0.7068 - val_loss: 5.2635e-05 - val_accuracy: 0.9772
# Epoch 2/100
# 105/105 [==============================] - 9s 81ms/step - loss: 3.3899e-04 - accuracy: 0.8376 - val_loss: 6.7543e-05 - val_accuracy: 0.8415
# Epoch 3/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.9555e-04 - accuracy: 0.8214 - val_loss: 5.0743e-05 - val_accuracy: 0.9796
# Epoch 4/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.6775e-04 - accuracy: 0.8424 - val_loss: 5.3333e-05 - val_accuracy: 0.7659
# Epoch 5/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.3862e-04 - accuracy: 0.8529 - val_loss: 2.7134e-05 - val_accuracy: 0.7887
# Epoch 6/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.0272e-04 - accuracy: 0.8589 - val_loss: 3.3674e-05 - val_accuracy: 0.9376
# Epoch 7/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.8207e-04 - accuracy: 0.8598 - val_loss: 1.4010e-05 - val_accuracy: 0.9364
# Epoch 8/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.5718e-04 - accuracy: 0.8676 - val_loss: 4.6841e-05 - val_accuracy: 0.8259
# Epoch 9/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.4216e-04 - accuracy: 0.8697 - val_loss: 2.4773e-05 - val_accuracy: 0.9700
# Epoch 10/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.3406e-04 - accuracy: 0.8761 - val_loss: 8.5037e-06 - val_accuracy: 0.9772
# Epoch 11/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.1857e-04 - accuracy: 0.8673 - val_loss: 1.5720e-05 - val_accuracy: 0.9436
# Epoch 12/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.1366e-04 - accuracy: 0.8709 - val_loss: 2.6126e-05 - val_accuracy: 0.8187
# Epoch 13/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.1106e-04 - accuracy: 0.8658 - val_loss: 1.0321e-05 - val_accuracy: 0.9856
# Epoch 14/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.0497e-04 - accuracy: 0.8733 - val_loss: 4.5596e-05 - val_accuracy: 0.8884
# Epoch 15/100
# 105/105 [==============================] - 9s 81ms/step - loss: 9.8092e-05 - accuracy: 0.8712 - val_loss: 9.6862e-06 - val_accuracy: 0.9556
# Epoch 16/100
# 105/105 [==============================] - 9s 81ms/step - loss: 9.3218e-05 - accuracy: 0.8694 - val_loss: 2.0201e-05 - val_accuracy: 0.7527
# Epoch 17/100
# 105/105 [==============================] - 8s 80ms/step - loss: 9.0538e-05 - accuracy: 0.8652 - val_loss: 1.1622e-05 - val_accuracy: 0.9652
# Epoch 18/100
# 105/105 [==============================] - 9s 81ms/step - loss: 8.4815e-05 - accuracy: 0.8634 - val_loss: 4.6012e-06 - val_accuracy: 0.9796
# Epoch 19/100
# 105/105 [==============================] - 9s 81ms/step - loss: 8.1961e-05 - accuracy: 0.8622 - val_loss: 1.4554e-05 - val_accuracy: 0.8067
# Epoch 20/100
# 105/105 [==============================] - 9s 81ms/step - loss: 8.0575e-05 - accuracy: 0.8718 - val_loss: 9.9522e-06 - val_accuracy: 0.9568
# Epoch 21/100
# 105/105 [==============================] - 9s 81ms/step - loss: 7.8554e-05 - accuracy: 0.8718 - val_loss: 9.4597e-06 - val_accuracy: 0.9796
# Epoch 22/100
# 105/105 [==============================] - 9s 81ms/step - loss: 7.0110e-05 - accuracy: 0.8773 - val_loss: 1.7706e-05 - val_accuracy: 0.8800
# Epoch 23/100
# 105/105 [==============================] - 9s 82ms/step - loss: 6.6898e-05 - accuracy: 0.8631 - val_loss: 9.5907e-06 - val_accuracy: 0.9580
# Epoch 24/100
# 105/105 [==============================] - 9s 81ms/step - loss: 6.4142e-05 - accuracy: 0.8718 - val_loss: 7.8620e-06 - val_accuracy: 0.9136
# Epoch 25/100
# 105/105 [==============================] - 9s 82ms/step - loss: 5.9849e-05 - accuracy: 0.8721 - val_loss: 1.2141e-05 - val_accuracy: 0.8151
# Epoch 26/100
# 105/105 [==============================] - 9s 82ms/step - loss: 5.6603e-05 - accuracy: 0.8779 - val_loss: 3.5493e-06 - val_accuracy: 0.9676
# Epoch 27/100
# 105/105 [==============================] - 9s 81ms/step - loss: 5.4849e-05 - accuracy: 0.8779 - val_loss: 1.2974e-05 - val_accuracy: 0.8115
# Epoch 28/100
# 105/105 [==============================] - 9s 81ms/step - loss: 4.9560e-05 - accuracy: 0.8806 - val_loss: 4.7732e-06 - val_accuracy: 0.9808
# Epoch 29/100
# 105/105 [==============================] - 8s 81ms/step - loss: 5.0431e-05 - accuracy: 0.8764 - val_loss: 6.8520e-06 - val_accuracy: 0.9196
# Epoch 30/100
# 105/105 [==============================] - 8s 81ms/step - loss: 4.6174e-05 - accuracy: 0.8776 - val_loss: 3.5159e-06 - val_accuracy: 0.9652
# Epoch 31/100
# 105/105 [==============================] - 8s 81ms/step - loss: 4.3657e-05 - accuracy: 0.8776 - val_loss: 9.2142e-06 - val_accuracy: 0.8703
# Epoch 32/100
# 105/105 [==============================] - 8s 80ms/step - loss: 4.0442e-05 - accuracy: 0.8848 - val_loss: 3.9334e-06 - val_accuracy: 0.9292
# Epoch 33/100
# 105/105 [==============================] - 8s 81ms/step - loss: 3.9796e-05 - accuracy: 0.8872 - val_loss: 7.6374e-06 - val_accuracy: 0.7767
# Epoch 34/100
# 105/105 [==============================] - 8s 80ms/step - loss: 3.7593e-05 - accuracy: 0.8875 - val_loss: 6.6412e-06 - val_accuracy: 0.9568
# Epoch 35/100
# 105/105 [==============================] - 8s 80ms/step - loss: 3.7770e-05 - accuracy: 0.8911 - val_loss: 6.8342e-06 - val_accuracy: 0.8451
# Epoch 36/100
# 105/105 [==============================] - 8s 81ms/step - loss: 3.4951e-05 - accuracy: 0.8869 - val_loss: 4.8837e-06 - val_accuracy: 0.9244
# Epoch 37/100
# 105/105 [==============================] - 8s 81ms/step - loss: 3.5902e-05 - accuracy: 0.8929 - val_loss: 2.9590e-06 - val_accuracy: 0.9784
# Epoch 38/100
# 105/105 [==============================] - 8s 81ms/step - loss: 3.3747e-05 - accuracy: 0.9013 - val_loss: 2.7067e-06 - val_accuracy: 0.9748
# Epoch 39/100
# 105/105 [==============================] - 8s 81ms/step - loss: 3.1137e-05 - accuracy: 0.9118 - val_loss: 3.6558e-06 - val_accuracy: 0.9532
# Epoch 40/100
# 105/105 [==============================] - 8s 81ms/step - loss: 3.0993e-05 - accuracy: 0.9025 - val_loss: 5.3998e-06 - val_accuracy: 0.8872
# Epoch 41/100
# 105/105 [==============================] - 8s 81ms/step - loss: 3.0553e-05 - accuracy: 0.9037 - val_loss: 5.8924e-06 - val_accuracy: 0.7899
# Epoch 42/100
# 105/105 [==============================] - 8s 81ms/step - loss: 2.9601e-05 - accuracy: 0.9070 - val_loss: 3.5901e-06 - val_accuracy: 0.9532
# Epoch 43/100
# 105/105 [==============================] - 8s 81ms/step - loss: 2.7899e-05 - accuracy: 0.9235 - val_loss: 4.0522e-06 - val_accuracy: 0.9796
# Epoch 44/100
# 105/105 [==============================] - 8s 81ms/step - loss: 2.6803e-05 - accuracy: 0.9280 - val_loss: 2.3264e-06 - val_accuracy: 0.9688
# Epoch 45/100
# 105/105 [==============================] - 8s 81ms/step - loss: 2.5155e-05 - accuracy: 0.9241 - val_loss: 3.6785e-06 - val_accuracy: 0.9388
# Epoch 46/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.5245e-05 - accuracy: 0.9346 - val_loss: 2.3361e-06 - val_accuracy: 0.9784
# Epoch 47/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.5385e-05 - accuracy: 0.9319 - val_loss: 2.7854e-06 - val_accuracy: 0.9508
# Epoch 48/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.3910e-05 - accuracy: 0.9424 - val_loss: 2.3813e-06 - val_accuracy: 0.9820
# Epoch 49/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.4951e-05 - accuracy: 0.9436 - val_loss: 4.1623e-06 - val_accuracy: 0.9844
# Epoch 50/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.4635e-05 - accuracy: 0.9421 - val_loss: 5.0725e-06 - val_accuracy: 0.9868
# Epoch 51/100
# 105/105 [==============================] - 9s 82ms/step - loss: 2.3021e-05 - accuracy: 0.9523 - val_loss: 1.0228e-05 - val_accuracy: 0.9652
# Epoch 52/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.2704e-05 - accuracy: 0.9670 - val_loss: 5.3672e-06 - val_accuracy: 0.9868
# Epoch 53/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.1355e-05 - accuracy: 0.9739 - val_loss: 1.9374e-06 - val_accuracy: 0.9856
# Epoch 54/100
# 105/105 [==============================] - 9s 82ms/step - loss: 2.2081e-05 - accuracy: 0.9727 - val_loss: 2.4642e-06 - val_accuracy: 0.9856
# Epoch 55/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.1054e-05 - accuracy: 0.9760 - val_loss: 3.6588e-06 - val_accuracy: 0.9856
# Epoch 56/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.1460e-05 - accuracy: 0.9730 - val_loss: 3.4487e-06 - val_accuracy: 0.9868
# Epoch 57/100
# 105/105 [==============================] - 9s 82ms/step - loss: 2.1126e-05 - accuracy: 0.9736 - val_loss: 2.3772e-06 - val_accuracy: 0.9868
# Epoch 58/100
# 105/105 [==============================] - 9s 81ms/step - loss: 2.0150e-05 - accuracy: 0.9760 - val_loss: 3.4309e-06 - val_accuracy: 0.9868
# Epoch 59/100
# 105/105 [==============================] - 9s 82ms/step - loss: 2.0230e-05 - accuracy: 0.9703 - val_loss: 4.2807e-06 - val_accuracy: 0.9868
# Epoch 60/100
# 105/105 [==============================] - 9s 82ms/step - loss: 2.0141e-05 - accuracy: 0.9721 - val_loss: 2.2428e-06 - val_accuracy: 0.9868
# Epoch 61/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.9994e-05 - accuracy: 0.9712 - val_loss: 4.5813e-06 - val_accuracy: 0.9808
# Epoch 62/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8902e-05 - accuracy: 0.9661 - val_loss: 6.6333e-06 - val_accuracy: 0.9868
# Epoch 63/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.9400e-05 - accuracy: 0.9664 - val_loss: 4.5225e-06 - val_accuracy: 0.9868
# Epoch 64/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.9171e-05 - accuracy: 0.9670 - val_loss: 3.0267e-06 - val_accuracy: 0.9868
# Epoch 65/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.9437e-05 - accuracy: 0.9637 - val_loss: 1.5577e-06 - val_accuracy: 0.9844
# Epoch 66/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8022e-05 - accuracy: 0.9667 - val_loss: 1.9031e-06 - val_accuracy: 0.9856
# Epoch 67/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.9413e-05 - accuracy: 0.9625 - val_loss: 2.1055e-06 - val_accuracy: 0.9868
# Epoch 68/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8683e-05 - accuracy: 0.9532 - val_loss: 3.4904e-06 - val_accuracy: 0.9856
# Epoch 69/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8744e-05 - accuracy: 0.9547 - val_loss: 2.0400e-06 - val_accuracy: 0.9868
# Epoch 70/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8911e-05 - accuracy: 0.9607 - val_loss: 4.1071e-06 - val_accuracy: 0.9712
# Epoch 71/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8362e-05 - accuracy: 0.9520 - val_loss: 2.8346e-06 - val_accuracy: 0.9856
# Epoch 72/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8508e-05 - accuracy: 0.9556 - val_loss: 2.5560e-06 - val_accuracy: 0.9832
# Epoch 73/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.7729e-05 - accuracy: 0.9520 - val_loss: 3.1385e-06 - val_accuracy: 0.9544
# Epoch 74/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.8023e-05 - accuracy: 0.9601 - val_loss: 2.5101e-06 - val_accuracy: 0.9868
# Epoch 75/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.7069e-05 - accuracy: 0.9625 - val_loss: 2.2949e-06 - val_accuracy: 0.9880
# Epoch 76/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.7261e-05 - accuracy: 0.9568 - val_loss: 1.9624e-06 - val_accuracy: 0.9832
# Epoch 77/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.7390e-05 - accuracy: 0.9565 - val_loss: 3.3512e-06 - val_accuracy: 0.9868
# Epoch 78/100
# 105/105 [==============================] - 8s 81ms/step - loss: 1.6827e-05 - accuracy: 0.9562 - val_loss: 3.4917e-06 - val_accuracy: 0.9868
# Epoch 79/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.6665e-05 - accuracy: 0.9541 - val_loss: 2.3407e-06 - val_accuracy: 0.9640
# Epoch 80/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.6382e-05 - accuracy: 0.9526 - val_loss: 2.7578e-06 - val_accuracy: 0.9868
# Epoch 81/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.6183e-05 - accuracy: 0.9547 - val_loss: 3.4244e-06 - val_accuracy: 0.9868
# Epoch 82/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.6203e-05 - accuracy: 0.9556 - val_loss: 2.0336e-06 - val_accuracy: 0.9592
# Epoch 83/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.6647e-05 - accuracy: 0.9613 - val_loss: 2.5894e-06 - val_accuracy: 0.9856
# Epoch 84/100
# 105/105 [==============================] - 8s 81ms/step - loss: 1.5965e-05 - accuracy: 0.9556 - val_loss: 3.7317e-06 - val_accuracy: 0.9796
# Epoch 85/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.6157e-05 - accuracy: 0.9541 - val_loss: 2.3194e-06 - val_accuracy: 0.9856
# Epoch 86/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.5725e-05 - accuracy: 0.9559 - val_loss: 1.9640e-06 - val_accuracy: 0.9856
# Epoch 87/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.6566e-05 - accuracy: 0.9487 - val_loss: 2.1215e-06 - val_accuracy: 0.9868
# Epoch 88/100
# 105/105 [==============================] - 8s 81ms/step - loss: 1.5673e-05 - accuracy: 0.9493 - val_loss: 3.0073e-06 - val_accuracy: 0.9868
# Epoch 89/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.6385e-05 - accuracy: 0.9511 - val_loss: 2.9199e-06 - val_accuracy: 0.9868
# Epoch 90/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.5315e-05 - accuracy: 0.9565 - val_loss: 2.8846e-06 - val_accuracy: 0.9868
# Epoch 91/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.5206e-05 - accuracy: 0.9580 - val_loss: 1.4745e-06 - val_accuracy: 0.9688
# Epoch 92/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.5768e-05 - accuracy: 0.9496 - val_loss: 1.9225e-06 - val_accuracy: 0.9868
# Epoch 93/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.5261e-05 - accuracy: 0.9565 - val_loss: 3.8943e-06 - val_accuracy: 0.9868
# Epoch 94/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.5053e-05 - accuracy: 0.9505 - val_loss: 3.2115e-06 - val_accuracy: 0.9844
# Epoch 95/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.5639e-05 - accuracy: 0.9559 - val_loss: 2.2391e-06 - val_accuracy: 0.9868
# Epoch 96/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.4971e-05 - accuracy: 0.9487 - val_loss: 2.8311e-06 - val_accuracy: 0.9868
# Epoch 97/100
# 105/105 [==============================] - 9s 82ms/step - loss: 1.5197e-05 - accuracy: 0.9502 - val_loss: 2.6776e-06 - val_accuracy: 0.9760
# Epoch 98/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.5481e-05 - accuracy: 0.9559 - val_loss: 3.8973e-06 - val_accuracy: 0.9880
# Epoch 99/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.5821e-05 - accuracy: 0.9514 - val_loss: 1.8842e-06 - val_accuracy: 0.9424
# Epoch 100/100
# 105/105 [==============================] - 9s 81ms/step - loss: 1.5268e-05 - accuracy: 0.9469 - val_loss: 2.9252e-06 - val_accuracy: 0.9844
# 27/27 [==============================] - 1s 21ms/step - loss: 2.9252e-06 - accuracy: 0.9844
# Validation Loss: [2.925156422861619e-06, 0.9843937754631042]

# %% [markdown]
# # Finish WandB

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▆▆▅▆▆▆▇▇▅█▇▆█████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂█▁▁▁▃</td></tr><tr><td>val_loss</td><td>█▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.6766</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>3e-05</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>8e-05</td></tr><tr><td>val_accuracy</td><td>0.61518</td></tr><tr><td>val_loss</td><td>5e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lyric-yogurt-5</strong> at: <a href='https://wandb.ai/ykhouchaf/calib_challenge/runs/ly2y21rc' target="_blank">https://wandb.ai/ykhouchaf/calib_challenge/runs/ly2y21rc</a><br/>Synced 6 W&B file(s), 1 media file(s), 40 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20230225_014328-ly2y21rc\logs</code>

# %% [markdown]
# * Plot

# %%
import matplotlib.pyplot as plt

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# Plot the first subplot with loss and validation loss
ax1.plot(history.history['loss'], label='loss')
ax1.plot(history.history['val_loss'], label='val_loss')
ax1.set_title('Loss vs Val_Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the second subplot with accuracy and validation accuracy
ax2.plot(history.history['accuracy'], label='accuracy')
ax2.plot(history.history['val_accuracy'], label='val_accuracy')
ax2.set_title('accuracy vs Val_accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Display the figure
plt.show()

# %% [markdown]
# # Predict

# %% [markdown]
# * Predict for one label video and save files

# %%
import numpy as np

# Define the path to the labeled videos
videos_path = '../labeled/'

# Define the path to the output files
output_path = '../folder/'

# Define the dimensions of the frames (assumed to be the same for all videos)
frame_width = 1920
frame_height = 1080

# Define the number of frames in each video (assumed to be the same for all videos)
num_frames = 1200

# file
i = 3

# Initialize arrays to store the predicted pitch and yaw angles for each frame in each video
pitch_angles = np.zeros((5, num_frames))
yaw_angles = np.zeros((5, num_frames))


# Load the video
video = cv2.VideoCapture(videos_path + str(i) + '.hevc')

# Initialize an empty list to store the frames for the current video
frames = []

# Iterate over each frame in the video
for j in range(num_frames):
    # Read the frame
    ret, frame = video.read()

    # Check if the frame was successfully read
    if not ret:
        break

    # Preprocess the frame
    frame = preprocess_frame(frame)

    # Make a prediction using the model
    prediction = model.predict(np.expand_dims(frame, axis=0))

    # Extract the pitch and yaw angles from the prediction
    pitch_angle, yaw_angle = prediction[0]

    # Store the pitch and yaw angles in the arrays
    pitch_angles[i, j] = pitch_angle
    yaw_angles[i, j] = yaw_angle

# Release the video object
video.release()

# Write the pitch and yaw angles to files
np.savetxt(output_path + str(i) + '.txt', np.vstack((pitch_angles[i], yaw_angles[i])).T)
# Out:
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step

# %% [markdown]
# * Plot my generated angles and initial angles

# %%
import numpy as np

# Define the path to the labeled videos and corresponding label files
labels_path = '../folder/'

# Define the number of frames in each video (assumed to be the same for all videos)
num_frames = 1200

# nparay for all angles
angles_predicted_labeled = []
angles_initial_labeled = []

# frames
frames = []

# Initialize an array to store the pitch and yaw angles for each frame
angles = []
i = 3

########################### predicted ###########################

# Load the predicted label file
labels = np.loadtxt(labels_path + str(i) + '.txt')

lenght_label = len(labels)
diff_lenght = num_frames - lenght_label

# Iterate over each frame in the video
for j in range(lenght_label):

    # Estimate the pitch and yaw angles for the current frame using the labels
    pitch = labels[j, 0]
    yaw = labels[j, 1]

    angles.append((pitch,yaw))

if diff_lenght > 0:
    for k in range(diff_lenght):
        angles.append((None,None))

# Convert the list of frames to a numpy array
angles_predicted_labeled = np.array(angles, dtype = np.float32)
print(f"Frames shape for video predicted : {angles_predicted_labeled.shape}")

########################### Labeled ###########################

labels_path = '../labeled/'
angles = []
frames = []
# Load the inital label file
labels = np.loadtxt(labels_path + str(i) + '.txt')

lenght_label = len(labels)
diff_lenght = num_frames - lenght_label

# Iterate over each frame in the video
for j in range(lenght_label):

    # Estimate the pitch and yaw angles for the current frame using the labels
    pitch = labels[j, 0]
    yaw = labels[j, 1]

    angles.append((pitch,yaw))

if diff_lenght > 0:
    for k in range(diff_lenght):
        angles.append((None,None))

# Convert the list of frames to a numpy array
angles_initial_labeled = np.array(angles, dtype = np.float32)
print(f"Frames shape for video labeled : {angles_initial_labeled.shape}")



# Find the indices of the rows containing NaN values in the first and second columns
nan_idx_0 = np.isnan(angles_initial_labeled[:,0])
nan_idx_1 = np.isnan(angles_initial_labeled[:,1])
# Replace the values in the first and second columns with NaN
angles_predicted_labeled[nan_idx_0,0] = np.nan
angles_predicted_labeled[nan_idx_1,1] = np.nan

# Print the shape of the frames and angles arrays after removing NaN values
print(f"Angles predicted: {angles_predicted_labeled.shape}")
print(f"Angles initial: {angles_initial_labeled.shape}")
# Out:
# Frames shape for video predicted : (1200, 2)
# Frames shape for video labeled : (1200, 2)
# Angles predicted: (1200, 2)
# Angles initial: (1200, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# Define two NumPy arrays for comparison
array1_pitch = angles_predicted_labeled[:, 0]
array2_pitch = angles_initial_labeled[:, 0]

# Plot the two arrays with different colors in the first subplot
ax1.plot(array1_pitch, 'b')
ax1.plot(array2_pitch, 'y')

# Add title and labels for the first subplot
ax1.set_title('Comparison of pitch angles')
ax1.set_xlabel('Index')
ax1.set_ylabel('Value')

# Define two NumPy arrays for comparison
array1_yaw = angles_predicted_labeled[:, 1]
array2_yaw = angles_initial_labeled[:, 1]

# Plot the two arrays with different colors in the second subplot
ax2.plot(array1_yaw, 'b')
ax2.plot(array2_yaw, 'y')

# Add title and labels for the second subplot
ax2.set_title('Comparison of yaw angles')
ax2.set_xlabel('Index')
ax2.set_ylabel('Value')

# Show the plot
plt.show()

# %%
model.save('model_180ep_HV_classic_36%')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_180ep_HV_classic_36%\assets
# INFO:tensorflow:Assets written to: model_180ep_HV_classic_36%\assets

# %% [markdown]
# * Predict for unlabeled videos and save files

# %%
import numpy as np

# Define the path to the unlabeled videos
videos_path = '../unlabeled/'

# Define the path to the output files
output_path = '../folder/outputs/'

# Define the dimensions of the frames (assumed to be the same for all videos)
frame_width = 1920
frame_height = 1080

# Define the number of frames in each video (assumed to be the same for all videos)
num_frames = 1200

# Initialize arrays to store the predicted pitch and yaw angles for each frame in each video
pitch_angles = np.zeros((5, num_frames))
yaw_angles = np.zeros((5, num_frames))

# Iterate over each video
for i in range(5):
    # Load the video
    video = cv2.VideoCapture(videos_path + str(i + 5) + '.hevc')

    # Initialize an empty list to store the frames for the current video
    frames = []

    # Iterate over each frame in the video
    for j in range(num_frames):
        # Read the frame
        ret, frame = video.read()

        # Check if the frame was successfully read
        if not ret:
            break

        # Preprocess the frame
        frame = preprocess_frame(frame)

        # Make a prediction using the model
        prediction = model.predict(np.expand_dims(frame, axis=0))

        # Extract the pitch and yaw angles from the prediction
        pitch_angle, yaw_angle = prediction[0]

        # Store the pitch and yaw angles in the arrays
        pitch_angles[i, j] = pitch_angle
        yaw_angles[i, j] = yaw_angle

    # Release the video object
    video.release()

    # Write the pitch and yaw angles to files
    np.savetxt(output_path + str(i + 5) + '.txt', np.vstack((pitch_angles[i], yaw_angles[i])).T)

# %%
Your plan looks like a good starting point for generating the labels for the unlabeled videos. Here are a few comments on your approach:

1- Loading the labeled videos and extracting the pitch and yaw angles for each frame is a good first step. This will provide you with the training data you need to train your model.

2- Loading the unlabeled videos and extracting the frames is also a good next step.

3- Preprocessing the frames by resizing and normalizing them is a good idea, as this can help improve the accuracy of your model.

4- Building a neural network model that takes in a frame and outputs the estimated pitch and yaw angles is a good approach. You may want to consider using a convolutional neural network (CNN) to learn features from the images, as this can be effective for image-based tasks.

5- Training the model using the labeled video data and evaluating its performance is essential to ensure that your model is accurate and effective. You may want to use metrics such as mean squared error (MSE) or mean absolute error (MAE) to evaluate the performance of your model.

6- Using the trained model to predict the pitch and yaw angles for each frame in the unlabeled videos is a good next step.

7- Saving the predicted pitch and yaw angles in 2D arrays and writing them to files 5.txt to 9.txt is a good final step.

Overall, your plan looks like a good approach to generate the labels for the unlabeled videos. Just keep in mind that it may require some iteration and adjustment based on your results. Good luck with your project!
